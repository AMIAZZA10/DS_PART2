# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/amiazza/Desktop/UK_Tourism Data_05.11.21.csv')

# %%
df
# Out:
#             Location                              Indicator  \
# 0      Aberdeen (UK)              % middle class households
# 1      Aberdeen (UK)              % middle class households
# 2      Aberdeen (UK)  Domestic nights in paid accommodation
# 3      Aberdeen (UK)  Domestic nights in paid accommodation
# 4      Aberdeen (UK)              Domestic overnight visits
# ...              ...                                    ...
# 5639  Sheffield (UK)   Total domestic travel spend (US$ mn)
# 5640  Sheffield (UK)    Total inbound travel spend (US$ mn)
# 5641  Sheffield (UK)    Total inbound travel spend (US$ mn)
# 5642  Sheffield (UK)                      Unemployment rate
# 5643  Sheffield (UK)                      Unemployment rate
#
#                          Origin                         Units     Scale  \
# 0                             -                             %       NaN
# 1                             -         % of total households         %
# ...

# %%
df.head()
# Out:
#         Location                              Indicator  \
# 0  Aberdeen (UK)              % middle class households
# 1  Aberdeen (UK)              % middle class households
# 2  Aberdeen (UK)  Domestic nights in paid accommodation
# 3  Aberdeen (UK)  Domestic nights in paid accommodation
# 4  Aberdeen (UK)              Domestic overnight visits
#
#                       Origin                         Units Scale  \
# 0                          -                             %   NaN
# 1                          -         % of total households     %
# 2  United Kingdom (Domestic)                             %   NaN
# 3  United Kingdom (Domestic)  Nights in paid accommodation  000s
# 4  United Kingdom (Domestic)                             %   NaN
#
#     Measurement     2010     2011     2012     2013  ...  Seasonally adjusted  \
# 0  % change y/y     0.57     4.84     2.96     2.32  ...                False
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2a851eda2e88> in <module>
# ----> 1 print(df)
#
# NameError: name 'df' is not defined
